# %%
import prepare
import explore

import matplotlib.pyplot as plt
import seaborn as sns

# %%
wine = prepare.all_data()

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6497 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  wine_type             6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 710.6+ KB

# %%
wine.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality wine_type
# 0      9.4        5       red
# 1      9.8        5       red

# %% [markdown]
# ### There are 4,898 different white wines and 1599 different red wines

# %%
wine.wine_type.value_counts()
# Out:
# wine_type
# white    4898
# red      1599
# Name: count, dtype: int64

# %%
wine.quality.value_counts()
# Out:
# quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64

# %%
## entered in to pipeline
cat,cont = explore.cat_or_cont(wine)

# %%
cat
# Out:
# ['quality']

# %%
cont
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol']

# %%
explore.ttest_viz(wine,cat,cont)
# Out:
# H_0 fixed acidity has no effect on quality
# H_a fixed acidity has an effect on quality
# Reject the null hypothesis: fixed acidity has an effect on quality. (p-value: 2.2044e-15)
#
#
# H_0 volatile acidity has no effect on quality
# H_a volatile acidity has an effect on quality
# Reject the null hypothesis: volatile acidity has an effect on quality. (p-value: 3.8392e-99)
#
#
# H_0 citric acid has no effect on quality
# H_a citric acid has an effect on quality
# Reject the null hypothesis: citric acid has an effect on quality. (p-value: 1.3076e-17)
#
#
# H_0 residual sugar has no effect on quality
# H_a residual sugar has an effect on quality
# Fail to reject the null hypothesis: No significant evidence to suggest that residual sugar affects quality. (p-value: 1.7342e-01)
#
#
# H_0 chlorides has no effect on quality
# H_a chlorides has an effect on quality
# Reject the null hypothesis: chlorides has an effect on quality. (p-value: 1.1636e-130)
#
#
# ...

# %% [markdown]
# ### observations from white vs red
# * red wide is more acidic distribution on fixed acidity and volitale acidity
# * red wine lower citric acid distribution
# * red wine highter in clorides dirstribuition
# * red wine lower in free sulfur dioxide
# * red wine lower in toal sulfur dioxide
# * red wine denser than white wine
# * red wine has a higher ph than white
# * red whine more sulfates than white

# %% [markdown]
# ## observations from quality
#
# * fixed acidity deserves a closer look for stat testing.
# * volatile acidity looks like it adversely effects quality.
# * citric acid needs stat testing
# * chrorides appears to affect quality
# * density appears to affect quality
# * alchohol strongly effects quality
# * quality most direct influencer of quality
# * white whines on average of higher wuality

# %% [markdown]
# ### Red vs White Questions to ask
# * Which wine red or white has more alchohol?
# * Does red or white have higher average quality?
# * How does density effect quality

# %%
### Observations from Quality 
*
# Out:
#   Cell In[11], line 2
#     *
#       ^
# SyntaxError: invalid syntax
